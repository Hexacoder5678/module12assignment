# %% [markdown]
# ANS 1 ==>
# <br>
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
#     <link rel="stylesheet" href="module12assignment.css">
# </head>
# <body>
#     <button id="prim">Primary Button</button>
#     <button id="sec">Seconadry button</button>
# </body>
# </html>
# <!--
# benefits of usinf var() :
#  .centralized styling
#  . cleaner,scalable,and dry
#  .easier theming and customization
#
#
# -->
# <!--below is thecss code-->
# :root{
#     --primary:#00b7ff;
#     --secondary:#6c757d;
# }
# #prim{
#     background-color: var(--primary);
#     color: white;
#     padding: 10px 20px;
#     border: none;
#     border-radius: 10px;
# }
# #sec{
#     background-color: var(--secondary);
#     color: white;
#     padding: 10px 20px;
#     border:none;
#     border-radius:10px;
# }

# %% [markdown]
# ANS 2==><BR><!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
#     <style>
#         body{
#             margin:0;
#             height: 100vh;
#             background: #f0f0f0;
#             display: flex;
#             align-items: center;
#             justify-content: center;
#             perspective: 800px;
#         }
#         .scene{
#             width: 200px;
#             height: 200px;
#             position: relative;
#             perspective: 800px;
#         }
#         .cube{
#             width: 100%;
#             height: 100%;
#             position:absolute;
#             transform-style: preserve-3d;
#             transform: rotateX(-30deg) rotateY(-30deg);
#             animation: rotate 10s infinite linear;
#         }
#         .face{
#             position:absolute;
#             width: 200px;
#             height: 200px;
#             background: rgba(0,102,255,0.8);
#             color: white;
#             display: flex;
#             align-items: center;
#             justify-content: center;
#             font-weight: bold;
#             font-size: 20px;
#             border:1px solid #000;
#         }
#
#         .front{ transform:translateZ(100px);}
#         .back{ transform:rotateY(180deg) (100px);}
#         .right{ transform:rotateY(90deg) (100px);}
#         .left{ transform: rotateY(-90deg) (100px);}
#         .top{ transform:rotateX(90deg) (100px);}
#         .bottom{ transform:rotateX(-90deg) (100px);}
#
#          @keyframes rotate {
#       from { transform: rotateX(-30deg) rotateY(-30deg); }
#       to   { transform: rotateX(-30deg) rotateY(330deg); }
#     }
#     </style>
# </head>
# <body>
#     <div class="scene">
#         <div class="cube">
#             <div class="face front">Front</div>
#             <div class="face back">Back</div>
#             <div class="face right">Right</div>
#             <div class="face left">Left</div>
#             <div class="face top">Top</div>
#             <div class="face bottom">Bottom</div>
#         </div>
#     </div>
# </body>
# </html>

# %% [markdown]
# ANS 3==><br>
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
#     <style>
#         body{
#             margin: 0;
#             height: 100vh;
#             background: #f0f0f0;
#             display: flex;
#             align-items: center;
#             justify-content: center;
#         }
#         .loader{
#             width: 40px;
#             height: 40px;
#             border:4px solid #ccc;
#             border-top: 4px solid #3498db;
#             border-radius: 50%;
#             animation: spin 1s linear infinite;
#         }
#
#         @keyframes spin {
#             0%{
#                 transform: rotate(0deg);
#             }
#             100%{
#                 transform: rotate(360deg);
#             }
#
#         }
#     </style>
# </head>
# <body>
#     <div class="loader"></div>
# </body>
# </html>
